# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelofabiani/desktop/blob/master/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns #libreria para graficos
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Primero activo google drive en este notebook
#Luego en google drive cree una carpeta llamada diplomado 
#Dentro de esta carpeta subi el csv crime.csv
#Asigno a la variable archivo el lugar donde esta el archivo subido
archivo="/content/drive/My Drive/diplomado/crime.csv"
#Veo que daba un error si lo queria abrir con solo colocar el nombre del archivo
#agregue el encoding y con eso abrio sin problema
df=pd.read_csv(archivo,encoding='windows-1252')
#Muestro las primeras 5 lineas del dataframe que importamos
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE  ...       Long                     Location
# 0      I182070945           619  ... -71.139371  (42.35779134, -71.13937053)
# 1      I182070943          1402  ... -71.060300  (42.30682138, -71.06030035)
# 2      I182070941          3410  ... -71.072429  (42.34658879, -71.07242943)
# 3      I182070940          3114  ... -71.078664  (42.33418175, -71.07866441)
# 4      I182070938          3114  ... -71.090361  (42.27536542, -71.09036101)
#
# [5 rows x 17 columns]

# %%
#verifico cuantas columnas y filas tiene el dataframe con el siguiente comando
df.shape
# Out:
# (319073, 17)

# %%
#Para mostrar algunas estadisticas utilizo el siguiente comando
df.describe()
# Out:
#         OFFENSE_CODE           YEAR  ...            Lat           Long
# count  319073.000000  319073.000000  ...  299074.000000  299074.000000
# mean     2317.546956    2016.560586  ...      42.214381     -70.908272
# std      1185.285543       0.996344  ...       2.159766       3.493618
# min       111.000000    2015.000000  ...      -1.000000     -71.178674
# 25%      1001.000000    2016.000000  ...      42.297442     -71.097135
# 50%      2907.000000    2017.000000  ...      42.325538     -71.077524
# 75%      3201.000000    2017.000000  ...      42.348624     -71.062467
# max      3831.000000    2018.000000  ...      42.395042      -1.000000
#
# [8 rows x 6 columns]

# %%
def show_values_on_bars(axs, h_v="v", space=0.4):
    def _show_on_single_plot(ax):
        if h_v == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height()
                value = int(p.get_height())
                ax.text(_x, _y, value, ha="center") 
        elif h_v == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height()
                value = int(p.get_width())
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

# %%
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(26, 15))


ax = sns.countplot(y="OFFENSE_CODE_GROUP", data=df)
show_values_on_bars(ax, "h", 0.3)
